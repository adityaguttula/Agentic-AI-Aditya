# %% [markdown]
# # Heading

# %% [markdown]
# ## Heading My Head

# %% [markdown]
# #### Heading

# %% [markdown]
# - My Head

# %% [markdown]
# - First Line
# - Second LIne
# - Third LIne
# - Hello *Blod Text*

# %% [markdown]
# #### INTEGER

# %%
a = 10
print(a)
b = 20
print(b)
def add_numbers(x, y):
    return x + y
print(add_numbers(a, b))    
result = add_numbers(a, b)
print("The sum of a and b is:", result)
# Out:
# 10
# 20
# 30
# The sum of a and b is: 30

# %% [markdown]
# #### FLOAT

# %%
a =10.55
print(a)
type (a)
# Out:
# 10.55
# float

# %% [markdown]
# #### STRINGS

# %%
name = '''hbvibvibvibivbibnjnbob[uh"btobontbont
jovbobvonbo
knbitbibvirbvir
hbvibvibvib
ljvrjbvooobjb[b[ig5
464494949]]'''
print(name)
type(name)
# Out:
# hbvibvibvibivbibnjnbob[uh"btobontbont
# jovbobvonbo
# knbitbibvirbvir
# hbvibvibvib
# ljvrjbvooobjb[b[ig5
# 464494949]]
# str

# %%
name = "Aditya"
print(name)
type(name)
# Out:
# Aditya
# str

# %% [markdown]
# #### BOLEAN (Its True or False)

# %%
#- True is equal to 1 and False is equal to 0 in Python.
is_active = True
print(int(is_active))
is_active = False
print(int(is_active))
# Out:
# 1
# 0

# %% [markdown]
# #### LISTS

# %%
fruits = ["apple", "banana", "cherry", "date", "elderberry", "fig", "grape", "honeydew", "kiwi", "lemon"]
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'date', 'elderberry', 'fig', 'grape', 'honeydew', 'kiwi', 'lemon']

# %%
fruits = ["apple", "banana", "cherry", "date", "elderberry", "fig", "grape", "honeydew", "lemon"]
print(fruits[0:10])  # This will print the elements at indices 8 and 9.
fruits[0] = "kiwi"
print (fruits)
# Out:
# ['apple', 'banana', 'cherry', 'date', 'elderberry', 'fig', 'grape', 'honeydew', 'lemon']
# ['kiwi', 'banana', 'cherry', 'date', 'elderberry', 'fig', 'grape', 'honeydew', 'lemon']

# %% [markdown]
# - We can use all the date types insie the list
# - Please remember python index will always start from "0" position (Example: Apple in zero'th position, Banana is in 1st position so on)
